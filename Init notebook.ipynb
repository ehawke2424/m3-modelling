# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# export PYTHONPATH="$PYTHONPATH:/shared-libs/python3.7/py/lib/python3.7/site-packages"
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting ase
#   Downloading ase-3.22.1-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 80.5 MB/s eta 0:00:00
# Collecting matscipy
#   Downloading matscipy-0.7.0.tar.gz (255 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.1/255.1 KB 42.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting ipywidgets==7.6.5
#   Downloading ipywidgets-7.6.5-py2.py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.8/121.8 KB 26.3 MB/s eta 0:00:00
# Requirement already satisfied: nbformat>=4.2.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (5.7.0)
# Requirement already satisfied: traitlets>=4.3.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (5.5.0)
# Collecting widgetsnbextension~=3.5.0
#   Downloading widgetsnbextension-3.5.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 99.5 MB/s eta 0:00:00
# Requirement already satisfied: ipython>=4.0.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (7.34.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (6.16.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (0.2.0)
# Collecting jupyterlab-widgets>=1.0.0
#   Downloading jupyterlab_widgets-3.0.5-py3-none-any.whl (384 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.3/384.3 KB 41.1 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.1.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from ase->-r ./requirements.txt (line 1)) (1.7.3)
# Requirement already satisfied: numpy>=1.15.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from ase->-r ./requirements.txt (line 1)) (1.21.6)
# Requirement already satisfied: matplotlib>=3.1.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from ase->-r ./requirements.txt (line 1)) (3.5.3)
# Requirement already satisfied: psutil in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (5.9.3)
# Requirement already satisfied: pyzmq>=17 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (24.0.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (7.4.3)
# Requirement already satisfied: nest-asyncio in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (1.5.6)
# Requirement already satisfied: packaging in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (21.3)
# Requirement already satisfied: tornado>=6.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (6.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (0.1.6)
# Requirement already satisfied: debugpy>=1.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (1.6.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (3.0.31)
# Requirement already satisfied: setuptools>=18.5 in /root/venv/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (47.1.0)
# Requirement already satisfied: pexpect>4.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (4.8.0)
# Requirement already satisfied: pygments in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (2.13.0)
# Requirement already satisfied: decorator in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (5.1.1)
# Requirement already satisfied: backcall in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (0.17.2)
# Requirement already satisfied: pickleshare in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (0.7.5)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib>=3.1.0->ase->-r ./requirements.txt (line 1)) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from matplotlib>=3.1.0->ase->-r ./requirements.txt (line 1)) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib>=3.1.0->ase->-r ./requirements.txt (line 1)) (4.37.4)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib>=3.1.0->ase->-r ./requirements.txt (line 1)) (9.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib>=3.1.0->ase->-r ./requirements.txt (line 1)) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from matplotlib>=3.1.0->ase->-r ./requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: jupyter-core in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (4.11.2)
# Requirement already satisfied: fastjsonschema in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (3.2.0)
# Requirement already satisfied: importlib-metadata>=3.6 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (5.0.0)
# Requirement already satisfied: notebook>=4.4.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (6.5.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from importlib-metadata>=3.6->nbformat>=4.2.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (4.4.0)
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from importlib-metadata>=3.6->nbformat>=4.2.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (3.9.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (0.7.1)
# Requirement already satisfied: attrs>=17.4.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (22.1.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (0.18.1)
# Requirement already satisfied: six>=1.11.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: entrypoints in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (0.4)
# Requirement already satisfied: nbconvert>=5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (6.4.5)
# Requirement already satisfied: Send2Trash>=1.8.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (1.8.0)
# Requirement already satisfied: nbclassic==0.4.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (0.4.5)
# Requirement already satisfied: terminado>=0.8.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (0.16.0)
# Requirement already satisfied: jinja2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (2.11.3)
# Requirement already satisfied: argon2-cffi in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (21.3.0)
# Requirement already satisfied: prometheus-client in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (0.15.0)
# Requirement already satisfied: notebook-shim>=0.1.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbclassic==0.4.5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: jupyter-server>=1.8 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbclassic==0.4.5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (1.21.0)
# Requirement already satisfied: ptyprocess>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (0.7.0)
# Requirement already satisfied: wcwidth in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (0.2.5)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (0.5.13)
# Requirement already satisfied: beautifulsoup4 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (4.11.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (1.5.0)
# Requirement already satisfied: defusedxml in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (0.7.1)
# Requirement already satisfied: testpath in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (0.6.0)
# Requirement already satisfied: bleach in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (5.0.1)
# Requirement already satisfied: jupyterlab-pygments in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (2.0.0)
# Requirement already satisfied: argon2-cffi-bindings in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (21.2.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jupyter-server>=1.8->nbclassic==0.4.5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (3.6.2)
# Requirement already satisfied: websocket-client in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jupyter-server>=1.8->nbclassic==0.4.5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (1.4.1)
# Requirement already satisfied: cffi>=1.0.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (2.3.2.post1)
# Requirement already satisfied: webencodings in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic==0.4.5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic==0.4.5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (3.4)
# Requirement already satisfied: pycparser in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r ./requirements.txt (line 3)) (2.21)
# Building wheels for collected packages: matscipy
#   Building wheel for matscipy (setup.py): started
#   Building wheel for matscipy (setup.py): finished with status 'done'
#   Created wheel for matscipy: filename=matscipy-0.7.0-cp37-cp37m-linux_x86_64.whl size=485651 sha256=cacc0669ff338e7f86819777910203af630b6bf74ed81796e8131ef4177876a3
#   Stored in directory: /root/.cache/pip/wheels/6c/48/4c/fbe8b9fbe6d804fa564b51df591efd4a04fa608147a8286647
# Successfully built matscipy
# Installing collected packages: matscipy, jupyterlab-widgets, ase, widgetsnbextension, ipywidgets
# Successfully installed ase-3.22.1 ipywidgets-7.6.5 jupyterlab-widgets-3.0.5 matscipy-0.7.0 widgetsnbextension-3.5.2
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=628e8107-5737-4f75-bd97-27a4383c3f52' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
